# %% [markdown]
# <a href="https://colab.research.google.com/github/JemimaAnila/SELF-STUDY-ANALYTICS/blob/main/Count_Occurence_of_String_in_Multiple_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install important packages
import pandas as pd
import numpy as np

# %%
#mount gdrive and read data source
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## Open folder that contains data
# %cd /content/gdrive/MyDrive
## data from https://carnextdoor.au.looker.com/explore/main/vehicles?qid=JpL8RirHKHhwVXt0hc2lQk&toggle=vis
df = pd.read_csv('main vehicles 2024-02-22T2222.csv')
display(df)
# Out:
# /content/gdrive/MyDrive
#     Owner ID  Cars ID                                   Cars Description  \
# 0      21764   228553  Looking for a daily use car to hire or for a r...
# 1      24478    14312  COVID-19 Treated\r\nSTRICTLY NO SMOKING.\r\nPl...
# 2      24478   232273  8 Seater- 4WD  Automatic - Family Luxurious Sp...
# 3      47712   174522  This UTE is a single CAB, which means only two...
# 4      52650     2881  This car uses our new bluetooth technology to ...
# ..       ...      ...                                                ...
# 71   1304669   253188  This has been a super reliable modern truck, d...
# 72   1398815   261575  "🎉 Get ready to experience the ultimate drivin...
# 73   1398815   261915  "Get ready to hit the road in style and comfor...
# 74   1398815   264778  Looking for a reliable and efficient rental ca...
# 75   1525244   270331  EXPERIENCE THIS RIDE\r\nThis 2018 SKODA Kodiaq...
#
#                          Cars Car manual instructions  \
# ...

# %%
#Rename
description = df.loc[:,'Cars Description']
manual = df.loc[:,'Cars Car manual instructions']
welcome = df.loc[:,'Cars Welcome Message']

# %%
#count occurences of Bluetooth Technology in each field
BT_Tech_in_Desc = description.str.count('bluetooth technology').sum()
BT_Tech_in_Manual= manual.str.count('bluetooth technology').sum()
BT_Tech_in_Welcome= welcome.str.count('bluetooth technology').sum()

print(BT_Tech_in_Desc,BT_Tech_in_Manual,BT_Tech_in_Welcome)
# Out:
# 12 5.0 3.0

# %%
#def function to search for the string in each field

def occurences(df, column, search_key):

  #convert data to lower case
    column_low = df[column].str.lower()
    search_key_low = search_key.lower()

  #count appearance of search string across entire colum

    key_appearance = df[column].str.count(search_key).sum()

    return key_appearance

# %%
a=occurences(df,'Cars Description','bluetooth technology')
b=occurences(df,'Cars Car manual instructions', 'bluetooth technology')
print(a,b)
# Out:
# 12 5.0

# %%
#def function to search for the string in each field

def occurences(df, column, search_key):

  #convert data to lower case
    column_upper = df[column].str.upper()
    search_key_upper = search_key.upper()

  #count appearance of search string across entire column
    key_appearance = df[df[column].str.count(search_key) >0]

    return key_appearance

# %%
occurences(df,'Cars Description','bluetooth technology')
# Out:
#     Owner ID  Cars ID                                   Cars Description  \
# 0      21764   228553  Looking for a daily use car to hire or for a r...
# 4      52650     2881  This car uses our new bluetooth technology to ...
# 5      52650   119942  This car uses our new bluetooth technology to ...
# 7      95395   247544  Meet Bluey Senior! 2021 MG HS Excite.\r\nIdeal...
# 19    169922    87368  This car uses our new bluetooth technology to ...
# 27    228273    17399  This car uses our new bluetooth technology to ...
# 33    370667   247151  **LIMITED TIME DISCOUNT - DOWN FROM $39 / DAY*...
# 34    461925   225347  Bluetooth capability that allows you to make\r...
# 40    542676   149129  Meet "Daisy" our little Suzuki Alto. \r\n\r\nT...
# 63   1069040   228117  Lovely easy to drive car perfect for casual or...
# 64   1125343   244268  This is Damme, our van. Van Damme. Jean Claude...
# 69   1227458   249262  Toyota Corolla Levin SX 2008 \r\n\r\nLooking f...
#
# ...
